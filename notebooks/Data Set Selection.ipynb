# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
cities = pd.read_csv('/Users/kellyshreeve/Desktop/Data-Sets/world-cities-density.csv')

# %%
cities.head(20)
# Out:
#     Unnamed: 0                   City      Population  Area (km²) Area (mi²)  \
# 0            0                   Malé      153,904[1]    1.956[1]      0.755
# 1            1                 Manila    1,660,714[2]    38.55[3]      14.88
# 2            2                  Bogor      866,034[4]    21.56[5]       8.32
# 3            3               Titagarh      124,213[6]     3.24[7]       1.25
# 4            4              Baranagar      250,768[6]     7.12[7]       2.75
# 5            5              Serampore      197,857[6]     5.88[7]       2.27
# 6            6           South Dumdum      392,444[6]    13.54[7]       5.23
# 7            7              Kamarhati      314,507[6]    10.96[7]       4.23
# 8            8                Kolkata    5,138,208[8]      185[9]       71.4
# 9            9       Levallois-Perret      66,082[10]    2.41[10]       0.93
# 10          10            Mandaluyong      305,576[2]    11.26[3]       4.35
# ...

# %%
ny = pd.read_csv('/Users/kellyshreeve/Desktop/Data-Sets/NY-Realstate-Pricing.csv')

# %%
ny.head(20)
# Out:
#     F1    id       neighbourhood  latitude  longitude        room_type  price  \
# 0    0  2595             Midtown  40.75362  -73.98377  Entire home/apt    225
# 1    1  3831            Brooklyn  40.68514  -73.95976  Entire home/apt     89
# 2    2  5099           Manhattan  40.74767  -73.97500  Entire home/apt    200
# 3    3  5121  Bedford-Stuyvesant  40.68688  -73.95596     Private room     60
# 4    4  5178           Manhattan  40.76489  -73.98493     Private room     79
# 5    6  5238     Lower East Side  40.71344  -73.99037  Entire home/apt    150
# 6    7  5441           Manhattan  40.76076  -73.98867     Private room     85
# 7    8  5803          Park Slope  40.66829  -73.98779     Private room     89
# 8    9  6090           Manhattan  40.73530  -74.00525  Entire home/apt    120
# 9   10  6848        Williamsburg  40.70837  -73.95352  Entire home/apt    140
# 10  11  7097            Brooklyn  40.69169  -73.97185  Entire home/apt    199
# ...

# %%
ny['room_type'].value_counts()
# Out:
# Entire home/apt    9405
# Private room       7752
# Shared room         357
# Hotel room          100
# Name: room_type, dtype: int64

# %%
ny['neighbourhood'].value_counts()
# Out:
# Brooklyn              3875
# Manhattan             3229
# Queens                1099
# Bedford-Stuyvesant     799
# Harlem                 632
#                       ...
# Sea Gate                 1
# Marble Hill              1
# Midland Beach            1
# Mill Basin               1
# Van Nest                 1
# Name: neighbourhood, Length: 186, dtype: int64

# %%
ny['neighbourhood'].unique()
# Out:
# array(['Midtown', 'Brooklyn', 'Manhattan', 'Bedford-Stuyvesant',
#        'Lower East Side', 'Park Slope', 'Williamsburg', 'East Village',
#        'Harlem', 'Hamilton Heights', 'Bushwick', 'Alphabet City',
#        'Flatbush', 'Long Island City', 'Clinton Hill', 'Fort Greene',
#        'Upper West Side', 'Greenpoint', 'Kips Bay', "Hell's Kitchen",
#        'East Harlem', 'Queens', 'Meatpacking District',
#        'Brooklyn Heights', 'Prospect Heights', 'Chelsea',
#        'Carroll Gardens', 'West Village', 'Gowanus', 'Lefferts Garden',
#        'Flatlands', 'Kew Garden Hills', 'Upper East Side', 'Sunnyside',
#        'DUMBO', 'Staten Island', 'Highbridge', 'Ridgewood', 'Jamaica',
#        'Middle Village', 'Cobble Hill', 'Roosevelt Island', 'Soho',
#        'West Brighton', 'Eastchester', 'Crown Heights',
#        'Morningside Heights', 'Chinatown', 'Red Hook',
#        'Kingsbridge Heights', 'The Rockaways', 'Midtown East',
# ...

# %%
cars = pd.read_csv('/Users/kellyshreeve/Desktop/Data-Sets/vehicles_us.csv')

# %%
cars.head(20)
# Out:
#     price  model_year                     model  condition  cylinders fuel  \
# 0    9400      2011.0                    bmw x5       good        6.0  gas
# 1   25500         NaN                ford f-150       good        6.0  gas
# 2    5500      2013.0            hyundai sonata   like new        4.0  gas
# 3    1500      2003.0                ford f-150       fair        8.0  gas
# 4   14900      2017.0              chrysler 200  excellent        4.0  gas
# 5   14990      2014.0              chrysler 300  excellent        6.0  gas
# 6   12990      2015.0              toyota camry  excellent        4.0  gas
# 7   15990      2013.0               honda pilot  excellent        6.0  gas
# 8   11500      2012.0               kia sorento  excellent        4.0  gas
# 9    9200      2008.0               honda pilot  excellent        NaN  gas
# 10  19500      2011.0  chevrolet silverado 1500  excellent        8.0  gas
# ...

# %%
nyc_delivery = pd.read_csv('/Users/kellyshreeve/Desktop/Data-Sets/nyc_food_delivery.csv')

# %%
nyc_delivery.head(20)
# Out:
#     order_id  customer_id             restaurant_name   cuisine_type  \
# 0    1477147       337525                     Hangawi         Korean
# 1    1477685       358141   Blue Ribbon Sushi Izakaya       Japanese
# 2    1477070        66393                 Cafe Habana        Mexican
# 3    1477334       106968   Blue Ribbon Fried Chicken       American
# 4    1478249        76942            Dirty Bird to Go       American
# 5    1477224       147468            Tamarind TriBeCa         Indian
# 6    1477894       157711           The Meatball Shop        Italian
# 7    1477859        89574                   Barbounia  Mediterranean
# 8    1477174       121706          Anjappar Chettinad         Indian
# 9    1477311        39705               Bukhara Grill         Indian
# 10   1477895       143926  Big Wong Restaurant _¤¾Ñ¼        Chinese
# 11   1478437       221206      Empanada Mama (closed)        Mexican
# 12   1476966       129969   Blue Ribbon Fried Chicken       American
# ...

# %%
nyc_delivery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1898 entries, 0 to 1897
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               1898 non-null   int64
#  1   customer_id            1898 non-null   int64
#  2   restaurant_name        1898 non-null   object
#  3   cuisine_type           1898 non-null   object
#  4   cost_of_the_order      1898 non-null   float64
#  5   day_of_the_week        1898 non-null   object
#  6   rating                 1898 non-null   object
#  7   food_preparation_time  1898 non-null   int64
#  8   delivery_time          1898 non-null   int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 133.6+ KB

# %%
nyc_delivery['cuisine_type'].value_counts()
# Out:
# American          584
# Japanese          470
# Italian           298
# Chinese           215
# Mexican            77
# Indian             73
# Middle Eastern     49
# Mediterranean      46
# Thai               19
# French             18
# Southern           17
# Korean             13
# Spanish            12
# Vietnamese          7
# Name: cuisine_type, dtype: int64

# %%
nyc_delivery['day_of_the_week'].value_counts()
# Out:
# Weekend    1351
# Weekday     547
# Name: day_of_the_week, dtype: int64

# %%
nyc_delivery.groupby('day_of_the_week')['cost_of_the_order'].plot(kind='hist', alpha=0.5, density=True, bins=30)
# Out:
# day_of_the_week
# Weekday    Axes(0.125,0.11;0.775x0.77)
# Weekend    Axes(0.125,0.11;0.775x0.77)
# Name: cost_of_the_order, dtype: object

# %%
nyc_delivery.groupby('day_of_the_week')['delivery_time'].plot(kind='hist', density=True, alpha=0.5, bins=20)
# Out:
# day_of_the_week
# Weekday    Axes(0.125,0.11;0.775x0.77)
# Weekend    Axes(0.125,0.11;0.775x0.77)
# Name: delivery_time, dtype: object

# %%
american_chinese = nyc_delivery[(nyc_delivery['cuisine_type']=='American') | (nyc_delivery['cuisine_type']=='Chinese')]

american_chinese.groupby('cuisine_type')['cost_of_the_order'].plot(kind='hist', density=True, alpha=0.5, bins=20)
# Out:
# cuisine_type
# American    Axes(0.125,0.11;0.775x0.77)
# Chinese     Axes(0.125,0.11;0.775x0.77)
# Name: cost_of_the_order, dtype: object

# %%
ev = pd.read_csv('/Users/kellyshreeve/Desktop/Data-Sets/ElectricCarData_Clean.csv')

# %%
ev.head(10)
# Out:
#          Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                       ID.3 Pure      10.0           160
# 2    Polestar                               2       4.7           210
# 3         BMW                            iX3        6.8           180
# 4       Honda                              e        9.5           145
# 5       Lucid                            Air        2.8           250
# 6  Volkswagen                         e-Golf        9.6           150
# 7     Peugeot                          e-208        8.1           150
# 8       Tesla     Model 3 Standard Range Plus       5.6           225
# 9        Audi                      Q4 e-tron        6.3           180
#
#    Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161            940         Yes        AWD
# ...

# %%
ev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            103 non-null    object
#  1   Model            103 non-null    object
#  2   AccelSec         103 non-null    float64
#  3   TopSpeed_KmH     103 non-null    int64
#  4   Range_Km         103 non-null    int64
#  5   Efficiency_WhKm  103 non-null    int64
#  6   FastCharge_KmH   103 non-null    object
#  7   RapidCharge      103 non-null    object
#  8   PowerTrain       103 non-null    object
#  9   PlugType         103 non-null    object
#  10  BodyStyle        103 non-null    object
#  11  Segment          103 non-null    object
#  12  Seats            103 non-null    int64
#  13  PriceEuro        103 non-null    int64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 11.4+ KB

# %%
ev['PriceEuro'].plot(kind='hist', edgecolor='black')

plt.show()

# %%
ev.groupby('PowerTrain')['PriceEuro'].plot(kind='hist', alpha=0.5, edgecolor='black')
# Out:
# PowerTrain
# AWD    Axes(0.125,0.11;0.775x0.77)
# FWD    Axes(0.125,0.11;0.775x0.77)
# RWD    Axes(0.125,0.11;0.775x0.77)
# Name: PriceEuro, dtype: object

# %%
ev.groupby('RapidCharge')['PriceEuro'].plot(kind='hist', alpha=0.5, density=True)
# Out:
# RapidCharge
# No     Axes(0.125,0.11;0.775x0.77)
# Yes    Axes(0.125,0.11;0.775x0.77)
# Name: PriceEuro, dtype: object

# %%
ev['Brand'].unique()
# Out:
# array(['Tesla ', 'Volkswagen ', 'Polestar ', 'BMW ', 'Honda ', 'Lucid ',
#        'Peugeot ', 'Audi ', 'Mercedes ', 'Nissan ', 'Hyundai ',
#        'Porsche ', 'MG ', 'Mini ', 'Opel ', 'Skoda ', 'Volvo ', 'Kia ',
#        'Renault ', 'Mazda ', 'Lexus ', 'CUPRA ', 'SEAT ', 'Lightyear ',
#        'Aiways ', 'DS ', 'Citroen ', 'Jaguar ', 'Ford ', 'Byton ',
#        'Sono ', 'Smart ', 'Fiat '], dtype=object)

# %%
ev['Brand'].value_counts()
# Out:
# Tesla          13
# Audi            9
# Nissan          8
# Volkswagen      8
# Skoda           6
# Renault         5
# Porsche         5
# Kia             5
# BMW             4
# Ford            4
# Smart           3
# Byton           3
# Mercedes        3
# Hyundai         3
# Opel            3
# Fiat            2
# Peugeot         2
# Honda           2
# Mini            1
# DS              1
# Polestar        1
# Sono            1
# Lucid           1
# Jaguar          1
# Citroen         1
# Aiways          1
# MG              1
# Lightyear       1
# SEAT            1
# CUPRA           1
# Lexus           1
# Mazda           1
# Volvo           1
# Name: Brand, dtype: int64

# %%
ev['BodyStyle'].value_counts()
# Out:
# SUV          45
# Hatchback    32
# Sedan        10
# Liftback      5
# Pickup        3
# Cabrio        3
# SPV           3
# MPV           1
# Station       1
# Name: BodyStyle, dtype: int64

# %%
suv_hatchback_sedan = ev[(ev['BodyStyle']=='SUV') | (ev['BodyStyle']=='Hatchback') | (ev['BodyStyle']=='Sedan')]

\suv_hatchback_sedan.groupby('BodyStyle')['PriceEuro'].plot(kind='hist', alpha=0.5, bins=12, edgecolor='black')
# Out:
# BodyStyle
# Hatchback    Axes(0.125,0.11;0.775x0.77)
# SUV          Axes(0.125,0.11;0.775x0.77)
# Sedan        Axes(0.125,0.11;0.775x0.77)
# Name: PriceEuro, dtype: object

# %%
tes_aud_nis = ev[(ev['Brand']=='Tesla ') | (ev['Brand']=='Audi ') | (ev['Brand']=='Nissan ') | (ev['Brand']=='Volkswagen ')]

# %%
tes_aud_nis_descrip = tes_aud_nis.pivot_table(index='Brand', values=['Range_Km', 'Efficiency_WhKm', 'PriceEuro'], aggfunc=['min', 'max', 'mean', 'median', 'std'])

display(tes_aud_nis_descrip)
# Out:
#                         min                                max            \
#             Efficiency_WhKm PriceEuro Range_Km Efficiency_WhKm PriceEuro
# Brand
# Audi                    188     55000      280             270    125000
# Nissan                  164     29234      190             232     65000
# Tesla                   153     45000      310             267    215000
# Volkswagen              166     21421      190             183     45000
#
#                                 mean                            \
#             Range_Km Efficiency_WhKm     PriceEuro    Range_Km
# Brand
# Audi             425      224.555556  80593.666667  356.666667
# Nissan           440      194.750000  45902.125000  328.125000
# Tesla            970      201.384615  80272.307692  500.769231
# Volkswagen       440      170.875000  34602.375000  318.125000
#
#                      median                                std                \
# ...

# %%
tes_aud_nis.groupby('Brand')['Range_Km'].plot(kind='hist', alpha=0.5, edgecolor='black')
# Out:
# Brand
# Audi           Axes(0.125,0.11;0.775x0.77)
# Nissan         Axes(0.125,0.11;0.775x0.77)
# Tesla          Axes(0.125,0.11;0.775x0.77)
# Volkswagen     Axes(0.125,0.11;0.775x0.77)
# Name: Range_Km, dtype: object
